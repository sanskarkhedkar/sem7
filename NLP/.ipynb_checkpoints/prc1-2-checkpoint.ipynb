# %%
import nltk
import spacy
from nltk.corpus import stopwords
from nltk.tokenize import sent_tokenize, word_tokenize

# %%
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ANURAJ\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ANURAJ\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\ANURAJ\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\ANURAJ\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
text = """Ich Heiße Anuraj, ich bin 21 jahre alt. ich studiere im MIT ADT Universität. Meine Freunde sind Vrushank, Ishan, Samarth, Pranav und Raj. Harish ist Imposter."""

# %%
text_lower = text.lower()
print(text_lower)
# Out:
# ich heiße anuraj, ich bin 21 jahre alt. ich studiere im mit adt universität. meine freunde sind vrushank, ishan, samarth, pranav und raj. harish ist imposter.

# %%
sent_tokens = sent_tokenize(text)
print(sent_tokens)
# Out:
# ['Ich Heiße Anuraj, ich bin 21 jahre alt.', 'ich studiere im MIT ADT Universität.', 'Meine Freunde sind Vrushank, Ishan, Samarth, Pranav und Raj.', 'Harish ist Imposter.']

# %%
tokens = word_tokenize(text)
print(tokens)
# Out:
# ['Ich', 'Heiße', 'Anuraj', ',', 'ich', 'bin', '21', 'jahre', 'alt', '.', 'ich', 'studiere', 'im', 'MIT', 'ADT', 'Universität', '.', 'Meine', 'Freunde', 'sind', 'Vrushank', ',', 'Ishan', ',', 'Samarth', ',', 'Pranav', 'und', 'Raj', '.', 'Harish', 'ist', 'Imposter', '.']

# %%
stop_words = set(stopwords.words('german'))
print("All standard Stop words:", stop_words)
print("Number of standard Stop words:", len(stop_words))
filtered_tokens = [word for word in tokens if word not in stop_words]
print("Tokens after Stopword Removal:", filtered_tokens)
# Out:
# All standard Stop words: {'muss', 'jedem', 'derer', 'ihrem', 'will', 'nun', 'des', 'solchem', 'dem', 'werden', 'dein', 'meiner', 'über', 'also', 'deiner', 'aller', 'jede', 'anderem', 'dasselbe', 'einig', 'gewesen', 'sonst', 'keinen', 'nicht', 'alle', 'dies', 'dazu', 'aber', 'meinen', 'ihr', 'im', 'mein', 'zur', 'keines', 'dann', 'zu', 'wie', 'dessen', 'unseres', 'jenes', 'anderr', 'diesem', 'jeden', 'auch', 'eurer', 'ist', 'solche', 'hab', 'weiter', 'ihres', 'was', 'derselben', 'jeder', 'er', 'oder', 'soll', 'die', 'jenem', 'euch', 'können', 'durch', 'keine', 'in', 'ihren', 'deines', 'viel', 'demselben', 'denn', 'nur', 'welche', 'anderer', 'damit', 'anderen', 'indem', 'deinem', 'etwas', 'wo', 'dieselbe', 'welches', 'zwischen', 'denselben', 'meine', 'selbst', 'jetzt', 'unter', 'dass', 'man', 'einiges', 'seines', 'doch', 'wir', 'machen', 'jene', 'habe', 'ins', 'wirst', 'andere', 'manches', 'warst', 'kann', 'würden', 'weil', 'manche', 'dieses', 'wollen', 'war', 'am', 'aus', 'mich', 'dir', 'den', 'hier', 'seinen', 'solchen', 'bist', 'du', 'einmal', 'euer', 'während', 'keinem', 'alles', 'als', 'das', 'haben', 'ihre', 'unser', 'wieder', 'manchem', 'eines', 'dich', 'meinem', 'nichts', 'waren', 'es', 'welcher', 'werde', 'zum', 'einem', 'desselben', 'seinem', 'sich', 'bis', 'noch', 'um', 'hinter', 'unsere', 'der', 'bin', 'hatten', 'jedes', 'würde', 'bei', 'andern', 'ein', 'ob', 'weg', 'ihn', 'euren', 'einiger', 'sind', 'wird', 'jenen', 'könnte', 'einige', 'eine', 'daß', 'solcher', 'diesen', 'uns', 'hat', 'unseren', 'zwar', 'eurem', 'da', 'hatte', 'musste', 'kein', 'meines', 'einigen', 'eure', 'an', 'seiner', 'unserem', 'vor', 'von', 'mit', 'einen', 'sein', 'und', 'derselbe', 'sie', 'ihnen', 'ander', 'auf', 'diese', 'welchen', 'gegen', 'eures', 'mancher', 'einigem', 'sehr', 'wollte', 'anders', 'für', 'deine', 'deinen', 'keiner', 'manchen', 'nach', 'ich', 'wenn', 'allem', 'sollte', 'anderm', 'solches', 'anderes', 'ihm', 'sondern', 'ihrer', 'mir', 'hin', 'so', 'vom', 'seine', 'welchem', 'dieser', 'jener', 'einer', 'dort', 'ohne', 'dieselben', 'allen'}
# Number of standard Stop words: 232
# Tokens after Stopword Removal: ['Ich', 'Heiße', 'Anuraj', ',', '21', 'jahre', 'alt', '.', 'studiere', 'MIT', 'ADT', 'Universität', '.', 'Meine', 'Freunde', 'Vrushank', ',', 'Ishan', ',', 'Samarth', ',', 'Pranav', 'Raj', '.', 'Harish', 'Imposter', '.']

# %%
from nltk import PorterStemmer
ps = PorterStemmer()
stemmed_tokens = [ps.stem(word) for word in filtered_tokens]
print("Stemmed Tokens:", stemmed_tokens)
# Out:
# Stemmed Tokens: ['ich', 'heiß', 'anuraj', ',', '21', 'jahr', 'alt', '.', 'studier', 'mit', 'adt', 'universität', '.', 'mein', 'freund', 'vrushank', ',', 'ishan', ',', 'samarth', ',', 'pranav', 'raj', '.', 'harish', 'impost', '.']

# %%
from nltk import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
lemmas = [lemmatizer.lemmatize(t) for t in tokens]
print(lemmas)
# Out:
# ['Ich', 'Heiße', 'Anuraj', ',', 'ich', 'bin', '21', 'jahre', 'alt', '.', 'ich', 'studiere', 'im', 'MIT', 'ADT', 'Universität', '.', 'Meine', 'Freunde', 'sind', 'Vrushank', ',', 'Ishan', ',', 'Samarth', ',', 'Pranav', 'und', 'Raj', '.', 'Harish', 'ist', 'Imposter', '.']

# %%
text2 = """मेरा नाम अनुराज है, मैं एमआईटी एडीटी में पढ़ता हूँ. मेरे दोस्त ईशान, वृषांक, समर्थ और प्रणव हैं"""

# %%
text2_lower = text2.lower()
print(text2_lower)
# Out:
# मेरा नाम अनुराज है, मैं एमआईटी एडीटी में पढ़ता हूँ. मेरे दोस्त ईशान, वृषांक, समर्थ और प्रणव हैं

# %%
sent_tokens = sent_tokenize(text2)
print(sent_tokens)
# Out:
# ['मेरा नाम अनुराज है, मैं एमआईटी एडीटी में पढ़ता हूँ.', 'मेरे दोस्त ईशान, वृषांक, समर्थ और प्रणव हैं']

# %%
tokens = word_tokenize(text2)
print(tokens)
# Out:
# ['मेरा', 'नाम', 'अनुराज', 'है', ',', 'मैं', 'एमआईटी', 'एडीटी', 'में', 'पढ़ता', 'हूँ', '.', 'मेरे', 'दोस्त', 'ईशान', ',', 'वृषांक', ',', 'समर्थ', 'और', 'प्रणव', 'हैं']

# %%
text3 = """Natural Language Processing tasks include tokenization, stemming, and lemmatization.
It is a field of Artificial Intelligence. Natural Language Processing is used in chatbots, sentiment analysis, and machine translation."""

# %%
# 1. Lowercasing
text_lower = text3.lower()
print("Lowercased Text:", text_lower)
# Out:
# Lowercased Text: natural language processing tasks include tokenization, stemming, and lemmatization.
# it is a field of artificial intelligence. natural language processing is used in chatbots, sentiment analysis, and machine translation.

# %%
# 2. Sentence Tokenization using NLTK
sentences1 = sent_tokenize(text3)
print("Sentence Tokenization using NLTK:")
print("Sentences:", sentences1)
# Out:
# Sentence Tokenization using NLTK:
# Sentences: ['Natural Language Processing tasks include tokenization, stemming, and lemmatization.', 'It is a field of Artificial Intelligence.', 'Natural Language Processing is used in chatbots, sentiment analysis, and machine translation.']

# %%
# 3. Word Tokenization
tokens1 = word_tokenize(text3)
print("Tokens:", tokens1)
# Out:
# Tokens: ['Natural', 'Language', 'Processing', 'tasks', 'include', 'tokenization', ',', 'stemming', ',', 'and', 'lemmatization', '.', 'It', 'is', 'a', 'field', 'of', 'Artificial', 'Intelligence', '.', 'Natural', 'Language', 'Processing', 'is', 'used', 'in', 'chatbots', ',', 'sentiment', 'analysis', ',', 'and', 'machine', 'translation', '.']

# %%
# 4. Stopword Removal
stop_words1 = set(stopwords.words('english'))
print("All standard Stop words:", stop_words1)
print("Number of standard Stop words:", len(stop_words1))
filtered_tokens1 = [word for word in tokens1 if word not in stop_words1]
print("Tokens after Stopword Removal:", filtered_tokens1)
# Out:
# All standard Stop words: {'will', 'are', 'each', 'over', "he'll", "haven't", "you'll", 'once', 'me', 'that', 'and', 'too', 'under', "aren't", 'same', 'just', 'does', 'off', "weren't", 'most', 'its', 'a', 'be', 'd', 'm', 'been', 'her', 'our', 'wasn', 'own', 'ma', 'until', 'for', 'have', 'himself', 'you', 'how', 'mightn', 'was', 'do', 'their', 'there', 'theirs', 'haven', 'in', 'then', "they'll", 'where', 'through', "he'd", 'all', 'of', 'with', 'during', 'hadn', 'hasn', 're', 'i', "i'm", "it'd", "i'll", 'no', 'only', "shan't", "couldn't", "she'll", "doesn't", "should've", 'itself', "shouldn't", 'these', 'they', 'when', 'hers', 'very', "needn't", 'mustn', 'who', "it's", 'further', 'isn', 'couldn', 'yourself', 'am', 'my', 'to', 'aren', 'can', 'having', 'than', "won't", 'him', "they're", 't', "they'd", "you've", 'we', 'while', "she's", 'against', 'not', 'didn', 'shan', 'should', "that'll", 'more', 'here', 'yours', 'myself', 'don', "mustn't", "hasn't", 'out', 'your', 'o', 'again', 'had', 'themselves', 'being', 'nor', 'wouldn', 'y', 'doesn', 'few', 'his', 'shouldn', 'ain', 'doing', "it'll", 'were', 've', "we're", "you're", 'an', 'below', "we'll", 'on', 'such', 'whom', 'from', 'it', "you'd", "i'd", 'the', 'herself', 'after', 'above', 'those', 'before', 'but', 'which', 'as', "didn't", 'now', 'why', 'about', 'because', 'what', 'down', 'needn', "she'd", 'won', "don't", 'between', 's', 'yourselves', 'did', "wasn't", 'them', 'up', 'weren', 'by', "we've", 'll', 'she', 'if', 'any', "hadn't", "we'd", "i've", 'this', "wouldn't", 'has', 'ours', 'at', 'into', "isn't", 'so', 'other', "mightn't", 'he', "they've", 'ourselves', 'some', "he's", 'is', 'both', 'or'}
# Number of standard Stop words: 198
# Tokens after Stopword Removal: ['Natural', 'Language', 'Processing', 'tasks', 'include', 'tokenization', ',', 'stemming', ',', 'lemmatization', '.', 'It', 'field', 'Artificial', 'Intelligence', '.', 'Natural', 'Language', 'Processing', 'used', 'chatbots', ',', 'sentiment', 'analysis', ',', 'machine', 'translation', '.']

# %%
# 5. Stemming
ps = PorterStemmer()
stemmed_tokens1 = [ps.stem(word) for word in filtered_tokens1]
print("Stemmed Tokens:", stemmed_tokens1)
# Out:
# Stemmed Tokens: ['natur', 'languag', 'process', 'task', 'includ', 'token', ',', 'stem', ',', 'lemmat', '.', 'it', 'field', 'artifici', 'intellig', '.', 'natur', 'languag', 'process', 'use', 'chatbot', ',', 'sentiment', 'analysi', ',', 'machin', 'translat', '.']

# %%
# 6. Lemmatization
lemmatizer = WordNetLemmatizer()
lemmas1 = [lemmatizer.lemmatize(t) for t in tokens1]
print(lemmas1)
# Out:
# ['Natural', 'Language', 'Processing', 'task', 'include', 'tokenization', ',', 'stemming', ',', 'and', 'lemmatization', '.', 'It', 'is', 'a', 'field', 'of', 'Artificial', 'Intelligence', '.', 'Natural', 'Language', 'Processing', 'is', 'used', 'in', 'chatbots', ',', 'sentiment', 'analysis', ',', 'and', 'machine', 'translation', '.']
