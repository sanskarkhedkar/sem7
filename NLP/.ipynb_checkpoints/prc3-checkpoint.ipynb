# %%
from docx import Document
from collections import Counter
import re
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 import fitz
#       2 from docx import Document
#       3 from collections import Counter
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\fitz\__init__.py:1
# ----> 1 from frontend import *
#       2 import tools
#       3 import os.path as op
#
# ModuleNotFoundError: No module named 'frontend'

# %%
def read_doc(file_path):
    doc = Document(file_path)
    full_text = " "
    for para in doc.paragraphs:
        full_text += para.text + " "
    return full_text

# %%
def tokenize(text):
    words = re.findall(r'\b\w+\b', text.lower())
    return words

# %%
file_path = "C:/Users/ANURAJ/Desktop/sample1.docx"
text = read_doc(file_path)
words = tokenize(text)
word_freq = Counter(words)
print("Word Frequencies:\n")
for word, freq in word_freq.items():
    print(f"{word}: {freq}")
# Out:
# Word Frequencies:
#
# hello: 1
# all: 1
# my: 4
# name: 2
# is: 5
# anuraj: 2
# and: 4
# i: 4
# study: 2
# in: 4
# mit: 3
# adt: 2
# university: 3
# pune: 1
# am: 1
# currently: 1
# electronics: 1
# computer: 1
# engineering: 1
# branch: 1
# also: 2
# chavan: 1
# have: 1
# many: 1
# friends: 3
# college: 1
# mostly: 1
# female: 1
# are: 2
# vrushank: 1
# ishan: 2
# male: 1
# samarth: 1
# pranav: 1
# raj: 1
# this: 1
# our: 1
# nlp: 1
# lab: 2
# always: 1
# late: 1
# to: 1
# the: 1
# he: 1
# mad: 1
# bad: 1

# %%
import fitz

# %%
def read_doc(pdf_path):
    doc1 = fitz.open(pdf_path)
    full_text1 = " "
    for page in doc1:
        full_text1 += page.get_text() + " "
    return full_text1

# %%
def tokenize(text):
    words1 = re.findall(r'\b\w+\b', text.lower())
    return words1

# %%
file_path = "C:/Users/ANURAJ/Desktop/sample1.pdf"
text1 = read_doc(file_path)
words1 = tokenize(text)
word_freq = Counter(words1)
print("Word Frequencies:\n")
for word1, freq1 in word_freq.items():
    print(f"{word1}: {freq1}")
# Out:
# Word Frequencies:
#
# hello: 1
# all: 1
# my: 4
# name: 2
# is: 5
# anuraj: 2
# and: 4
# i: 4
# study: 2
# in: 4
# mit: 3
# adt: 2
# university: 3
# pune: 1
# am: 1
# currently: 1
# electronics: 1
# computer: 1
# engineering: 1
# branch: 1
# also: 2
# chavan: 1
# have: 1
# many: 1
# friends: 3
# college: 1
# mostly: 1
# female: 1
# are: 2
# vrushank: 1
# ishan: 2
# male: 1
# samarth: 1
# pranav: 1
# raj: 1
# this: 1
# our: 1
# nlp: 1
# lab: 2
# always: 1
# late: 1
# to: 1
# the: 1
# he: 1
# mad: 1
# bad: 1
