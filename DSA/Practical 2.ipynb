# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.array([1,2,3,4])
y=x*2

plt.plot(x,y)
plt.show()

# %%
x=[1,2,3,4,5]
y=[2,4,6,8,10]
plt.figure(figsize=(8,6))
plt.plot(x,y,marker='o',linestyle='-')

for i,(xi,yi) in enumerate(zip(x,y)):
    plt.annotate(f'({xi},{yi})',(xi, yi), textcoords="offset points",xytext=(0,10),ha='center')
plt.title("Line chart with Annotate")
plt.xlabel('X axis label')
plt.ylabel('Y axis label')
plt.grid(True)
plt.show()

# %%
x = np.array([1, 2, 3, 4])
y = x*2

plt.plot(x, y)
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Any suitable title")
plt.show()  # show first chart

plt.figure()
x1 = [2, 4, 6, 8]
y1 = [3, 5, 7, 9]
plt.plot(x1, y1, '-.')
plt.show()

# %%
x = np.array([1, 2, 3, 4])
y = x*2

# first plot with X and Y data
plt.plot(x, y)

x1 = [2, 4, 6, 8]
y1 = [3, 5, 7, 9]

# second plot with x1 and y1 data
plt.plot(x1, y1, '-.')

plt.xlabel("X-axis data")
plt.ylabel("Y-axis data")
plt.title('multiple plots')
plt.show()

# %%
x = np.array([1, 2, 3, 4])
y = x*2

plt.plot(x, y)

x1 = [2, 4, 6, 8]
y1 = [3, 5, 7, 9]

plt.plot(x, y1, '-.')
plt.xlabel("X-axis data")
plt.ylabel("Y-axis data")
plt.title('multiple plots')

plt.fill_between(x, y, y1, color='green', alpha=0.5)
plt.show()

# %%
import numpy as np  # useful for many scientific computing in Python
import pandas as pd # primary data structure library
from __future__ import print_function # adds compatibility to python 2
# !pip install xlrd
df_can1 = pd.read_excel('https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DV0101EN/labs/Data_Files/Canada.xlsx',
                       sheet_name='Canada by Citizenship',
                       skiprows=range(20),
                       skipfooter=2)


print ('Data read into a pandas dataframe!')
df_can1.head()
df_can1.shape
# Out:
# ...
# Data read into a pandas dataframe!
# (195, 43)

# %%
df_can1.info()
df_can1.columns.values 

df_can1.index.values

print(type(df_can1.columns))
print(type(df_can1.index))

df_can1.columns.tolist()
df_can1.index.tolist()

print (type(df_can1.columns.tolist()))
print (type(df_can1.index.tolist()))

# in pandas axis=0 represents rows (default) and axis=1 represents columns.
df_can1.drop(['AREA','REG','DEV','Type','Coverage'], axis=1, inplace=True)
df_can1.head(2)

df_can1.rename(columns={'OdName':'Country', 'AreaName':'Continent', 'RegName':'Region'}, inplace=True)
df_can1.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 195 entries, Afghanistan to Zimbabwe
# Data columns (total 38 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Continent  195 non-null    object
#  1   Region     195 non-null    object
#  2   DevName    195 non-null    object
#  3   1980       195 non-null    int64
#  4   1981       195 non-null    int64
#  5   1982       195 non-null    int64
#  6   1983       195 non-null    int64
#  7   1984       195 non-null    int64
#  8   1985       195 non-null    int64
#  9   1986       195 non-null    int64
#  10  1987       195 non-null    int64
#  11  1988       195 non-null    int64
#  12  1989       195 non-null    int64
#  13  1990       195 non-null    int64
#  14  1991       195 non-null    int64
#  15  1992       195 non-null    int64
#  16  1993       195 non-null    int64
#  17  1994       195 non-null    int64
#  18  1995       195 non-null    int64
# ...

# %%
df_can.dtypes
# Out:
# Country      object
# Continent    object
# Region       object
# DevName      object
# 1980          int64
# 1981          int64
# 1982          int64
# 1983          int64
# 1984          int64
# 1985          int64
# 1986          int64
# 1987          int64
# 1988          int64
# 1989          int64
# 1990          int64
# 1991          int64
# 1992          int64
# 1993          int64
# 1994          int64
# 1995          int64
# 1996          int64
# 1997          int64
# 1998          int64
# 1999          int64
# 2000          int64
# 2001          int64
# 2002          int64
# 2003          int64
# 2004          int64
# 2005          int64
# 2006          int64
# 2007          int64
# 2008          int64
# 2009          int64
# 2010          int64
# 2011          int64
# 2012          int64
# 2013          int64
# dtype: object

# %%
df_can1['Total'] = df_can1.apply(pd.to_numeric, errors='coerce').sum(axis=1)

# %%
df_can1.shape
# Out:
# (195, 38)

# %%
df_can1.isnull().sum()
df_can1.describe()

#df_can1.Country
# Out:
#                1980          1981          1982          1983          1984  \
# count    195.000000    195.000000    195.000000    195.000000    195.000000
# mean     508.394872    566.989744    534.723077    387.435897    376.497436
# std     1949.588546   2152.643752   1866.997511   1204.333597   1198.246371
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%       13.000000     10.000000     11.000000     12.000000     13.000000
# 75%      251.500000    295.500000    275.000000    173.000000    181.000000
# max    22045.000000  24796.000000  20620.000000  10015.000000  10170.000000
#
#               1985         1986          1987          1988          1989  \
# count   195.000000   195.000000    195.000000    195.000000    195.000000
# mean    358.861538   441.271795    691.133333    714.389744    843.241026
# ...

# %%
df_can1[(df_can1['Continent']=='Asia') & (df_can1['Region']=='Southern Asia’)]

print ('data dimensions:', df_can1.shape)  ## to See changes done
print(df_can1.columns)
df_can1.head(2)
# Out:
#   Cell In[92], line 1
#     df_can1[(df_can1['Continent']=='Asia') & (df_can1['Region']=='Southern Asia’)]
#                                                                  ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
import matplotlib.pyplot as plt

haiti = df_can1.loc['Haiti', years] # Passing in years 1980 - 2013 to exclude the 'total' column
haiti.head()

haiti.plot()

haiti.plot(kind='line')

plt.title('Immigration from Haiti')
plt.ylabel('Number of immigrants')
plt.xlabel('Years')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[94], line 3
#       1 import matplotlib.pyplot as plt
# ----> 3 haiti = df_can1.loc['Haiti', years] # Passing in years 1980 - 2013 to exclude the 'total' column
#       4 haiti.head()
#       6 haiti.plot()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1184, in _LocationIndexer.__getitem__(self, key)
#    1182     if self._is_scalar_access(key):
#    1183         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#    1187     axis = self.axis or 0
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1368, in _LocIndexer._getitem_tuple(self, tup)
#    1366 with suppress(IndexingError):
#    1367     tup = self._expand_ellipsis(tup)
# ...

# %%
import matplotlib.pyplot as plt

# Make sure your year columns are strings

years = list(map(str, range(1980, 2013)))

# Select data for Haiti across the specified years
haiti = df_can1.loc['Haiti', years]

# Plot
haiti.plot(kind='line')

# Add labels and title
plt.title('Immigration from Haiti to Canada (1980 - 2013)')
plt.ylabel('Number of Immigrants')
plt.xlabel('Year')
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[98], line 8
#       5 years = list(map(str, range(1980, 2013)))
#       7 # Select data for Haiti across the specified years
# ----> 8 haiti = df_can1.loc['Haiti', years]
#      10 # Plot
#      11 haiti.plot(kind='line')
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1184, in _LocationIndexer.__getitem__(self, key)
#    1182     if self._is_scalar_access(key):
#    1183         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#    1187     axis = self.axis or 0
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1368, in _LocIndexer._getitem_tuple(self, tup)
#    1366 with suppress(IndexingError):
#    1367     tup = self._expand_ellipsis(tup)
# ...

# %%
df_can1.set_index('Country', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9440\1498619997.py in ?()
# ----> 1 df_can1.set_index('Country', inplace=True)
#
# ~\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    6118                     if not found:
#    6119                         missing.append(col)
#    6120
#    6121         if missing:
# -> 6122             raise KeyError(f"None of {missing} are in the columns")
#    6123
#    6124         if inplace:
#    6125             frame = self
#
# KeyError: "None of ['Country'] are in the columns"
